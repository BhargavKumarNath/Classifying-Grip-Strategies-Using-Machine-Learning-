# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/CourseWork/Dissertation Classifying grip strategies using machine learning/data/02_processed/combined_trajectory_data.csv")
df.head()
# Out:
# C:\Users\bharg\AppData\Local\Temp\ipykernel_28740\467060874.py:1: DtypeWarning: Columns (5,6,22,23,24,89,90) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:/CourseWork/Dissertation Classifying grip strategies using machine learning/data/02_processed/combined_trajectory_data.csv")
#    subjName  trialN  frameN      time visCond surface distance  indexXraw  \
# 0         1       1       0  0.000000   clear   black    three   0.064798
# 1         1       1       1  0.008333   clear   black    three   0.064706
# 2         1       1       2  0.016667   clear   black    three   0.064627
# 3         1       1       3  0.025000   clear   black    three   0.064533
# 4         1       1       4  0.033333   clear   black    three   0.064459
#
#    indexYraw  indexZraw  ...  GPVel  GPAcc  GOF  GOT  GOS  timeRaw  illusion  \
# 0   0.100376   0.033471  ...    NaN    NaN  NaN  NaN  NaN      NaN       NaN
# ...

# %%
df["grip_strategy_label"].unique()
# Out:
# array(['aiming_clear_black_three', 'aiming_clear_black_two',
#        'aiming_clear_wood_three', 'aiming_clear_wood_one',
#        'aiming_clear_wood_two', 'aiming_clear_black_one',
#        'aiming_mono_black_three', 'aiming_mono_black_two',
#        'aiming_mono_wood_three', 'aiming_mono_wood_one',
#        'aiming_mono_wood_two', 'aiming_mono_black_one',
#        'aiming_bino_black_three', 'aiming_bino_black_two',
#        'aiming_bino_wood_three', 'aiming_bino_wood_one',
#        'aiming_bino_wood_two', 'aiming_bino_black_one',
#        'prehension_clear_black_near', 'prehension_clear_black_far',
#        'prehension_clear_wood_middle', 'prehension_clear_black_middle',
#        'prehension_clear_wood_near', 'prehension_clear_wood_far',
#        'prehension_strong_black_near', 'prehension_strong_black_far',
#        'prehension_strong_wood_middle', 'prehension_strong_black_middle',
#        'prehension_strong_wood_near', 'prehension_strong_wood_far',
# ...
